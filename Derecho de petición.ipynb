# %%
# INFORMACION PRELIMINAR

# En este campo se establece la información que inicialmente tiene que brindar el interesado.
from datetime import date
pet_nom = input ('Ingrese sus nombres y apellidos\n').upper()
ciudad = input('¿En qué ciudad te encuentras? (Incluye el Departamento)\n').capitalize() 
fecha = date.today()
ced_pet = input('¿Cuál es tu número de documento?:\n')
exped_pet = input('¿En qué ciudad se expidió tu documento de identidad?:\n').capitalize()
direccion = input('¿Cuál es tu dirección física?:\n')


def email_pedido(email_persona):
    while True:
        email = input(f'''¿Cuál es el correo electrónico del {email_persona}? \n''').lower()
        if '@' in email:
            break
        if '@' not in email:
            print('Ingrese un correo electrónico valido (Ej. @gmail.com)')
            continue
        return email
email_pet = email_pedido('propio')#poner como mejor va dirigida a

ado_nom = input('¿A quién va dirigido el Derecho de petición?: \n').upper()
direccion_ado =input('¿Cuál es la dirección física de la persona a quien va dirigido el Derecho de petición?:\n')

email_ado = email_pedido('peticionado')


asunto = input('En máximo diez palabras, ¿cuál es el asunto de tu Derecho de petición?:\n').upper()# se peude limitar con un len y un while

def contador(clase_escrito):
    hechos = []
    primer_hecho = input(f"""¿cuál es tu primer {clase_escrito}?\n""")
    hechos.append(primer_hecho)
    contador = 1 
    while True :
        otrohecho = input(f"""¿tienes otro {clase_escrito} que añadir? (si/no)\n""")
        if otrohecho == 'si':
            contador = contador + 1
            cual_hecho = input(f'''describe el {clase_escrito} numero {contador}\n''')
            hechos.append(cual_hecho) 
            continue
        if otrohecho == 'no':
            break   
    return  hechos
# Hechos.
hechos = contador('hecho')
# Peticiones.
peticiones = contador('petición')

 
tipodoc = 'c.c'
#peticionario_tipodedocumento = input('¿Cuál es tu tipo de documento? (Puede ser Cédula de ciudadanía, Cédula de extranjería, Pasaporte o Permiso Especial de Permanencia): ')
calidad = 'ciudadano' #también puede ser servidor público etc
#peticionario_calidad = input('¿En qué calidad actuas? (Puede ser como ciudadano, como interesado, o en representación de otra persona, caso en el cual, deberás específicar el nombre y la identificación de tu representado): ')



#:::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::Petición:::::::::::::::::::::::::::::::::::::::

peticion_par1 = f"""{ciudad} {fecha}

Señores. 
{ado_nom}
{direccion_ado}
{email_ado}

Referencia: Derecho de Petición de {pet_nom} a {ado_nom} para {asunto}

{pet_nom}, identificado(a) con {tipodoc} número {ced_pet} de {exped_pet}, en calidad de {calidad}; de conformidad con el artículo 23 de la Constitución Política de Colombia de 1991, y del título segundo de la parte primera del Código de Procedimiento Administrativo y de lo Contencioso Administrativo (Ley 1437 de 2011); interpongo el siguiente Derecho de Petición basado en los siguientes:


i). Hechos.
{hechos}


ii). Petición.

En mérito de lo expuesto, se solicita a {ado_nom} que:

Petición 
{peticiones}
"""

peticion_par5=f"""vi). Notificaciones.

Se podrá notificar en cualquiera de las siguientes direcciones.

{direccion}

{email_pet}


vii).Firma.

El presente documento se suscribe de conformidad con el artículo 7 de la Ley 527 de 1999, y con la presunción contemplada en el artículo 244 de la Ley 1564 de 2012 (Código General del Proceso).



Sin otro particular,



{pet_nom}
{tipodoc}- número {ced_pet}"""
#¿programar texto pruebas?

def pruebas():
    peticion_par2= f'''iii). Pruebas.
    Dentro del presente trámite se solicita se tengan como pruebas:
    {pruebas}\n '''
def anexos():
    peticion_par3 = f"""iv). Anexos.
    Se anexan dentro del presente Derecho de petición todos los archivos relacionados en el acápite de pruebas, y los siguientes documentos.
    {anexos}\n"""
def documentos():
    peticion_par4 = f"""v). Documentos especiales requeridos por ley.
    {documentos}\n"""
#pruebas
pruebas = input ('¿tienes que allegar una prueba? (si/no)\n') 
#anexos
anexos = input ('¿tienes que allegar un anexo? (si/no)\n')  
# Documentos exigidos por ley.
doc_ley = input ('¿tienes que allegar por ley un documento? (si/no)\n')
if pruebas == 'si' and anexos == 'si':
    
    anexos = contador('anexo')
    pruebas = contador('prueba')
    pruebas()
    anexos()
    print(peticion_par1+peticion_par2+peticion_par3+peticion_par5)
    
elif anexos == 'si':
    anexos = contador('anexo')
    anexos()
    print(peticion_par1+peticion_par3+peticion_par5)
elif doc_ley == 'si':
    documentos = contador ('documento')
    documentos()
    print(peticion_par1+peticion_par3+peticion_par4)
elif anexos == 'si'and doc_ley == 'si' and pruebas =='si':
    anexos()
    documentos()
    print(peticion_par1+peticion_par2 + peticion_par3+peticion_par4+peticion_par5)
else:
    print(peticion_par1+peticion_par5)
# Out:
# Ingrese sus nombres y apellidos
# ds
# ¿En qué ciudad te encuentras? (Incluye el Departamento)
# ds
# ¿Cuál es tu número de documento?:
# dsf
# ¿En qué ciudad se expidió tu documento de identidad?:
# dsf
# ¿Cuál es tu dirección física?:
# fds
# ¿Cuál es el correo electrónico del propio?
# dsf
# Ingrese un correo electrónico valido (Ej. @gmail.com)
# ¿Cuál es el correo electrónico del propio?
# dsf@
# ¿A quién va dirigido el Derecho de petición?:
# asd
# ¿Cuál es la dirección física de la persona a quien va dirigido el Derecho de petición?:
# sad
# ¿Cuál es el correo electrónico del peticionado?
# asdsd@
# En máximo diez palabras, ¿cuál es el asunto de tu Derecho de petición?:
# sadsadsad
# ¿cuál es tu primer hecho?
# 1
# ¿tienes otro hecho que añadir? (si/no)
# no
# ['1']
# ¿cuál es tu primer petición?
# qweqwe
# ¿tienes otro petición que añadir? (si/no)
# no
# ['qweqwe']
# ¿tienes que allegar una prueba? (si/no)
# wqewqeqweno
# ¿tienes que allegar un anexo? (si/no)
# qweqwewqeno
# ¿tienes que allegar por ley un documento? (si/no)
# ewqewqeqwe
# Ds 2021-04-21
#
# Señores.
# ASD
# sad
# None
#
# Referencia: Derecho de Petición de DS a ASD para SADSADSAD
#
# DS, identificado(a) con c.c número dsf de Dsf, en calidad de ciudadano; de conformidad con el artículo 23 de la Constitución Política de Colombia de 1991, y del título segundo de la parte primera del Código de Procedimiento Administrativo y de lo Contencioso Administrativo (Ley 1437 de 2011); interpongo el siguiente Derecho de Petición basado en los siguientes:
#
#
# i). Hechos.
# ['1']
#
#
# ii). Petición.
#
# En mérito de lo expuesto, se solicita a ASD que:
#
# Petición
# ['qweqwe']
# vi). Notificaciones.
#
# Se podrá notificar en cualquiera de las siguientes direcciones.
#
# fds
#
# None
#
#
# vii).Firma.
#
# El presente documento se suscribe de conformidad con el artículo 7 de la Ley 527 de 1999, y con la presunción contemplada en el artículo 244 de la Ley 1564 de 2012 (Código General del Proceso).
#
#
#
# Sin otro particular,
#
#
#
# DS
# c.c- número dsf

# %%
# Out:
# Ingrese sus nombres y apellidosj
# En qué ciudad te encuentrasj
# ¿cuál es tu cédula?j
# ¿dónde fu expedida?j
# cuál es tu direcciónj
# ¿Cuál es el correo electrónico?
# @
# ¿a quién va dirigida la petición?jojo
# cuál es el asunto de la peticiónyoque sé
# ¿cuál es tu primer hecho?uno
# ¿tienes otro hecho que añadir? (si/no)no
# ['uno']
# ¿cuál es tu primer petición?1
# ¿tienes otro petición que añadir? (si/no)no
# ['1']
# ¿cuál es tu primer prueba?123
# ¿tienes otro prueba que añadir? (si/no)no
# ['123']
# ¿tienes que allegar un anexo? (si/no)no
# ¿tienes que allegar por ley un documento? (si/no)no
# J 2021-04-20
#
# Señores.
# J
# j
# @
#
# Referencia: Derecho de Petición de J a JOJO para YOQUE SÉ
#
# J, identificado(a) con c.c número j de J, en calidad de ciudadano; de conformidad con el artículo 23 de la Constitución Política de Colombia de 1991, y del título segundo de la parte primera del Código de Procedimiento Administrativo y de lo Contencioso Administrativo (Ley 1437 de 2011); interpongo el siguiente Derecho de Petición basado en los siguientes:
#
#
# i). Hechos.
# ['uno']
#
#
# ii). Petición.
#
# En mérito de lo expuesto, se solicita a JOJO que:
#
# Petición
# ['1']
#
#
# iii). Pruebas.
#
# Dentro del presente trámite se solicita se tengan como pruebas:
#
# ['123'] vi). Notificaciones.
#
# Se podrá notificar en cualquiera de las siguientes direcciones.
#
# j
#
# @
#
#
# vii).Firma.
#
# El presente documento se suscribe de conformidad con el artículo 7 de la Ley 527 de 1999, y con la presunción contemplada en el artículo 244 de la Ley 1564 de 2012 (Código General del Proceso).
#
#
#
# Sin otro particular,
#
#
#
# J
# c.c- número j

# %% [markdown]
# ### from datetime import date
# fecha = date.today()
# print('hoy es', fecha)

# %%
def contador(clase_escrito):
    clase = clase_escrito
    hechos = []
    primer_hecho = input(f"""¿cuál es tu primer {clase_escrito}?""")
    hechos.append(primer_hecho)
    contador = 1 
    while True :
        otrohecho = input(f"""¿tienes otro {clase_escrito} que añadir? (si/no)""")
        if otrohecho == 'si':
            contador = contador + 1
            cual_hecho = input(f'''describe el {clase_escrito} numero {contador}''')
            hechos.append(cual_hecho) 
            continue
        if otrohecho == 'no':
            print(hechos)
            break   
    return  hechos
contador('hechos')
hechos = contador('petición')
print(hechos)
numerales = 0
for i in hechos :
    numerales
# Out:
#   File "<ipython-input-9-da8a6e55aec5>", line 22
#     hechos{i+1}.{hechos[i]}
#           ^
# SyntaxError: invalid syntax
